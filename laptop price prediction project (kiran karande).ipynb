# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv(r"C:\Users\Akash\Desktop\Data Science\Machine Learning\Practice dataset\laptops.csv")
df
# Out:
#      Unnamed: 0                                           img_link  \
# 0             0  https://rukminim1.flixcart.com/image/312/312/x...
# 1             1  https://rukminim1.flixcart.com/image/312/312/x...
# 2             2  https://rukminim1.flixcart.com/image/312/312/l...
# 3             3  https://rukminim1.flixcart.com/image/312/312/x...
# 4             4  https://rukminim1.flixcart.com/image/312/312/x...
# ..          ...                                                ...
# 979         979  https://rukminim1.flixcart.com/image/312/312/k...
# 980         980  https://rukminim1.flixcart.com/image/312/312/k...
# 981         981  https://rukminim1.flixcart.com/image/312/312/x...
# 982         982  https://rukminim1.flixcart.com/image/312/312/k...
# 983         983  https://rukminim1.flixcart.com/image/312/312/x...
#
#                                          name  price(in Rs.)  \
# 0               Lenovo Intel Core i5 11th Gen          62990
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 984 entries, 0 to 983
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        984 non-null    int64
#  1   img_link          984 non-null    object
#  2   name              984 non-null    object
#  3   price(in Rs.)     984 non-null    int64
#  4   processor         984 non-null    object
#  5   ram               984 non-null    object
#  6   os                984 non-null    object
#  7   storage           984 non-null    object
#  8   display(in inch)  984 non-null    float64
#  9   rating            688 non-null    float64
#  10  no_of_ratings     688 non-null    float64
#  11  no_of_reviews     688 non-null    float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 92.4+ KB

# %%
df.head(2)
# Out:
#    Unnamed: 0                                           img_link  \
# 0           0  https://rukminim1.flixcart.com/image/312/312/x...
# 1           1  https://rukminim1.flixcart.com/image/312/312/x...
#
#                              name  price(in Rs.)  \
# 0   Lenovo Intel Core i5 11th Gen          62990
# 1  Lenovo V15 G2 Core i3 11th Gen          37500
#
#                             processor             ram  \
# 0  Intel Core i5 Processor (11th Gen)  16 GB DDR4 RAM
# 1  Intel Core i3 Processor (11th Gen)   8 GB DDR4 RAM
#
#                                    os              storage  display(in inch)  \
# 0         Windows 11 Operating System           512 GB SSD              15.6
# 1  64 bit Windows 11 Operating System  1 TB HDD|256 GB SSD              15.6
#
#    rating  no_of_ratings  no_of_reviews
# 0     4.5           14.0            1.0
# 1     4.4           53.0            3.0

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'img_link', 'name', 'price(in Rs.)', 'processor', 'ram',
#        'os', 'storage', 'display(in inch)', 'rating', 'no_of_ratings',
#        'no_of_reviews'],
#       dtype='object')

# %%
df.drop(['Unnamed: 0', 'img_link','rating', 'no_of_ratings','no_of_reviews'],axis =1,inplace=True)

# %%
df
# Out:
#                                          name  price(in Rs.)  \
# 0               Lenovo Intel Core i5 11th Gen          62990
# 1              Lenovo V15 G2 Core i3 11th Gen          37500
# 2        ASUS TUF Gaming F15 Core i5 10th Gen          49990
# 3    ASUS VivoBook 15 (2022) Core i3 10th Gen          33990
# 4                     Lenovo Athlon Dual Core          18990
# ..                                        ...            ...
# 979         ASUS VivoBook 15 Core i3 10th Gen          37990
# 980       HP Chromebook MediaTek Kompanio 500          22670
# 981                    ASUS Ryzen 5 Hexa Core          54990
# 982            DELL Inspiron Core i3 11th Gen          40990
# 983           ASUS Celeron Dual Core 10th Gen          24540
#
#                                         processor               ram  \
# 0              Intel Core i5 Processor (11th Gen)    16 GB DDR4 RAM
# 1              Intel Core i3 Processor (11th Gen)     8 GB DDR4 RAM
# ...

# %%
df.isnull().sum()
# Out:
# name                0
# price(in Rs.)       0
# processor           0
# ram                 0
# os                  0
# storage             0
# display(in inch)    0
# dtype: int64

# %%
df.describe()
# Out:
#        price(in Rs.)  display(in inch)
# count     984.000000        984.000000
# mean    80960.720528         15.148374
# std     57421.220919          1.332078
# min     15990.000000         11.600000
# 25%     42655.000000         14.000000
# 50%     62990.000000         15.600000
# 75%     94990.000000         15.600000
# max    419990.000000         35.000000

# %%
df.columns
# Out:
# Index(['name', 'price(in Rs.)', 'processor', 'ram', 'os', 'storage',
#        'display(in inch)'],
#       dtype='object')

# %%
df
# Out:
#                                          name  price(in Rs.)  \
# 0               Lenovo Intel Core i5 11th Gen          62990
# 1              Lenovo V15 G2 Core i3 11th Gen          37500
# 2        ASUS TUF Gaming F15 Core i5 10th Gen          49990
# 3    ASUS VivoBook 15 (2022) Core i3 10th Gen          33990
# 4                     Lenovo Athlon Dual Core          18990
# ..                                        ...            ...
# 979         ASUS VivoBook 15 Core i3 10th Gen          37990
# 980       HP Chromebook MediaTek Kompanio 500          22670
# 981                    ASUS Ryzen 5 Hexa Core          54990
# 982            DELL Inspiron Core i3 11th Gen          40990
# 983           ASUS Celeron Dual Core 10th Gen          24540
#
#                                         processor               ram  \
# 0              Intel Core i5 Processor (11th Gen)    16 GB DDR4 RAM
# 1              Intel Core i3 Processor (11th Gen)     8 GB DDR4 RAM
# ...

# %%
df.isnull().sum()
# Out:
# name                0
# price(in Rs.)       0
# processor           0
# ram                 0
# os                  0
# storage             0
# display(in inch)    0
# dtype: int64

# %%
df.head()
# Out:
#                                        name  price(in Rs.)  \
# 0             Lenovo Intel Core i5 11th Gen          62990
# 1            Lenovo V15 G2 Core i3 11th Gen          37500
# 2      ASUS TUF Gaming F15 Core i5 10th Gen          49990
# 3  ASUS VivoBook 15 (2022) Core i3 10th Gen          33990
# 4                   Lenovo Athlon Dual Core          18990
#
#                             processor             ram  \
# 0  Intel Core i5 Processor (11th Gen)  16 GB DDR4 RAM
# 1  Intel Core i3 Processor (11th Gen)   8 GB DDR4 RAM
# 2  Intel Core i5 Processor (10th Gen)   8 GB DDR4 RAM
# 3  Intel Core i3 Processor (10th Gen)   8 GB DDR4 RAM
# 4      AMD Athlon Dual Core Processor   4 GB DDR4 RAM
#
#                                    os              storage  display(in inch)
# 0         Windows 11 Operating System           512 GB SSD              15.6
# 1  64 bit Windows 11 Operating System  1 TB HDD|256 GB SSD              15.6
# ...

# %%
df.tail()
# Out:
#                                     name  price(in Rs.)  \
# 979    ASUS VivoBook 15 Core i3 10th Gen          37990
# 980  HP Chromebook MediaTek Kompanio 500          22670
# 981               ASUS Ryzen 5 Hexa Core          54990
# 982       DELL Inspiron Core i3 11th Gen          40990
# 983      ASUS Celeron Dual Core 10th Gen          24540
#
#                                         processor               ram  \
# 979            Intel Core i3 Processor (10th Gen)     8 GB DDR4 RAM
# 980      MediaTek MediaTek Kompanio 500 Processor  4 GB LPDDR4X RAM
# 981               AMD Ryzen 5 Hexa Core Processor     8 GB DDR4 RAM
# 982            Intel Core i3 Processor (11th Gen)     8 GB DDR4 RAM
# 983  Intel Celeron Dual Core Processor (10th Gen)     4 GB DDR4 RAM
#
#                                      os              storage  display(in inch)
# 979  64 bit Windows 10 Operating System             1 TB HDD              15.6
# ...

# %%
feature = df.iloc[:,[0,2,3,4,5,6]]
target = df.iloc[:,1]

# %%
feature
# Out:
#                                          name  \
# 0               Lenovo Intel Core i5 11th Gen
# 1              Lenovo V15 G2 Core i3 11th Gen
# 2        ASUS TUF Gaming F15 Core i5 10th Gen
# 3    ASUS VivoBook 15 (2022) Core i3 10th Gen
# 4                     Lenovo Athlon Dual Core
# ..                                        ...
# 979         ASUS VivoBook 15 Core i3 10th Gen
# 980       HP Chromebook MediaTek Kompanio 500
# 981                    ASUS Ryzen 5 Hexa Core
# 982            DELL Inspiron Core i3 11th Gen
# 983           ASUS Celeron Dual Core 10th Gen
#
#                                         processor               ram  \
# 0              Intel Core i5 Processor (11th Gen)    16 GB DDR4 RAM
# 1              Intel Core i3 Processor (11th Gen)     8 GB DDR4 RAM
# 2              Intel Core i5 Processor (10th Gen)     8 GB DDR4 RAM
# 3              Intel Core i3 Processor (10th Gen)     8 GB DDR4 RAM
# ...

# %%
target
# Out:
# 0      62990
# 1      37500
# 2      49990
# 3      33990
# 4      18990
#        ...
# 979    37990
# 980    22670
# 981    54990
# 982    40990
# 983    24540
# Name: price(in Rs.), Length: 984, dtype: int64

# %%
plt.figure(figsize=(8,4))
sns.boxplot(data=feature,x=target)
plt.grid()
plt.show()

# %%
plt.figure(figsize=(5,4))
sns.boxplot(data=feature,x=target,y="name")
# Out:
# <AxesSubplot:xlabel='price(in Rs.)', ylabel='name'>

# %%
# Made a function for getting only companies name from data

# %%
def company(x):
    return x.split()[0]

# %%
feature["name"].apply(company)
# Out:
# 0      Lenovo
# 1      Lenovo
# 2        ASUS
# 3        ASUS
# 4      Lenovo
#         ...
# 979      ASUS
# 980        HP
# 981      ASUS
# 982      DELL
# 983      ASUS
# Name: name, Length: 984, dtype: object

# %%
feature["brand"] = feature["name"].apply(company)

# %%
feature["name"].value_counts()
# Out:
# Lenovo Intel Core i5 11th Gen                   43
# Lenovo V15 G2 Core i3 11th Gen                  28
# DELL Vostro Ryzen 3 Quad Core 5425U             27
# Lenovo IdeaPad 3 Core i3 11th Gen               16
# Lenovo Intel Core i3 11th Gen                   16
#                                                 ..
# DELL G15 Ryzen 5 Hexa Core AMD R5                1
# ASUS ASUS TUF Dash F15 Core i7 12th Gen          1
# ASUS VivoBook Ultra Ryzen 7 Octa Core AMD R7     1
# DELL Insprion 3511 Core i3 11th Gen              1
# ASUS Celeron Dual Core 10th Gen                  1
# Name: name, Length: 506, dtype: int64

# %%
feature
# Out:
#                                          name  \
# 0               Lenovo Intel Core i5 11th Gen
# 1              Lenovo V15 G2 Core i3 11th Gen
# 2        ASUS TUF Gaming F15 Core i5 10th Gen
# 3    ASUS VivoBook 15 (2022) Core i3 10th Gen
# 4                     Lenovo Athlon Dual Core
# ..                                        ...
# 979         ASUS VivoBook 15 Core i3 10th Gen
# 980       HP Chromebook MediaTek Kompanio 500
# 981                    ASUS Ryzen 5 Hexa Core
# 982            DELL Inspiron Core i3 11th Gen
# 983           ASUS Celeron Dual Core 10th Gen
#
#                                         processor               ram  \
# 0              Intel Core i5 Processor (11th Gen)    16 GB DDR4 RAM
# 1              Intel Core i3 Processor (11th Gen)     8 GB DDR4 RAM
# 2              Intel Core i5 Processor (10th Gen)     8 GB DDR4 RAM
# 3              Intel Core i3 Processor (10th Gen)     8 GB DDR4 RAM
# ...

# %%
newfeature = feature.iloc[:,[1,2,3,4,5,6]]
newtarget = df.iloc[:,1]

# %%
newfeature
# Out:
#                                         processor               ram  \
# 0              Intel Core i5 Processor (11th Gen)    16 GB DDR4 RAM
# 1              Intel Core i3 Processor (11th Gen)     8 GB DDR4 RAM
# 2              Intel Core i5 Processor (10th Gen)     8 GB DDR4 RAM
# 3              Intel Core i3 Processor (10th Gen)     8 GB DDR4 RAM
# 4                  AMD Athlon Dual Core Processor     4 GB DDR4 RAM
# ..                                            ...               ...
# 979            Intel Core i3 Processor (10th Gen)     8 GB DDR4 RAM
# 980      MediaTek MediaTek Kompanio 500 Processor  4 GB LPDDR4X RAM
# 981               AMD Ryzen 5 Hexa Core Processor     8 GB DDR4 RAM
# 982            Intel Core i3 Processor (11th Gen)     8 GB DDR4 RAM
# 983  Intel Celeron Dual Core Processor (10th Gen)     4 GB DDR4 RAM
#
#                                      os              storage  \
# 0           Windows 11 Operating System           512 GB SSD
# ...

# %%
newtarget
# Out:
# 0      62990
# 1      37500
# 2      49990
# 3      33990
# 4      18990
#        ...
# 979    37990
# 980    22670
# 981    54990
# 982    40990
# 983    24540
# Name: price(in Rs.), Length: 984, dtype: int64

# %%
# Plotted a countplot for visualizing the value counts of individual brands from data

# %%
plt.figure(figsize=(10,6))
sns.countplot(data=newfeature,y=newfeature['brand'])
plt.show()

# %%
newfeature["brand"].value_counts()
# Out:
# ASUS         230
# Lenovo       228
# DELL         162
# HP           156
# acer          59
# MSI           52
# APPLE         38
# Infinix       23
# GIGABYTE       6
# Avita          6
# realme         5
# ALIENWARE      4
# SAMSUNG        3
# RedmiBook      2
# LG             2
# Vaio           2
# Ultimus        2
# Mi             1
# MICROSOFT      1
# lenovo         1
# Nokia          1
# Name: brand, dtype: int64

# %%
# Plotted a countplot for visualizing the value counts of Processor's  from data

# %%
plt.figure(figsize=(10,10))
sns.countplot(data=newfeature,y=newfeature['processor'])
plt.show()

# %%
newfeature["processor"].value_counts()
# Out:
# Intel Core i3 Processor (11th Gen)              131
# Intel Core i5 Processor (11th Gen)              129
# Intel Core i5 Processor (12th Gen)              101
# AMD Ryzen 5 Hexa Core Processor                  93
# AMD Ryzen 7 Octa Core Processor                  83
# Intel Core i7 Processor (12th Gen)               65
# AMD Ryzen 3 Quad Core Processor                  36
# Intel Core i5 Processor (10th Gen)               31
# Intel Core i3 Processor (10th Gen)               30
# Intel Core i7 Processor (10th Gen)               26
# Intel Core i7 Processor (11th Gen)               26
# Intel Celeron Dual Core Processor                23
# AMD Ryzen 9 Octa Core Processor                  20
# AMD Ryzen 3 Dual Core Processor                  20
# Intel Core i5 Processor (8th Gen)                16
# Apple M1 Processor                               14
# Apple M2 Processor                               13
# Intel Core i9 Processor (12th Gen)               13
# ...

# %%
# Plotted a countplot for visualizing the value counts of ram from data

# %%
plt.figure(figsize=(10,6))
sns.countplot(data=newfeature,y=newfeature['ram'])
plt.show()

# %%
newfeature["ram"].value_counts()
# Out:
# 8 GB DDR4 RAM               463
# 16 GB DDR4 RAM              235
# 16 GB DDR5 RAM               72
# 4 GB DDR4 RAM                45
# 8 GB LPDDR4X RAM             23
# 16 GB LPDDR5 RAM             22
# 32 GB DDR5 RAM               21
# 16 GB LPDDR4X RAM            18
# 4 GB LPDDR4 RAM              14
# 16 GB Unified Memory RAM     13
# 8 GB DDR5 RAM                12
# 8 GB Unified Memory RAM       9
# 32 GB DDR4 RAM                7
# 8 GB DDR3 RAM                 7
# 32 GB LPDDR5 RAM              5
# 4 GB LPDDR4X RAM              5
# 16 GB LPDDR3 RAM              5
# 8 GB LPDDR3 RAM               4
# 32 GB Unified Memory RAM      1
# 16 GB LPDDR4 RAM              1
# 32 GB LPDDR4X RAM             1
# 16 GB DDR3 RAM                1
# Name: ram, dtype: int64

# %%
# Plotted a countplot for visualizing the value counts of Operating System's from data

# %%
plt.figure(figsize=(10,6))
sns.countplot(data=newfeature,y=newfeature['os'])
plt.show()

# %%
newfeature["os"].value_counts()
# Out:
# 64 bit Windows 11 Operating System    527
# 64 bit Windows 10 Operating System    195
# Windows 11 Operating System           183
# Mac OS Operating System                38
# Windows 10 Operating System            16
# Chrome Operating System                 8
# DOS Operating System                    6
# 64 bit Chrome Operating System          6
# 32 bit Windows 11 Operating System      3
# 64 bit DOS Operating System             1
# 64 bit Windows 8 Operating System       1
# Name: os, dtype: int64

# %%
# Plotted a countplot for visualizing the value counts of Storage from data

# %%
plt.figure(figsize=(10,10))
sns.countplot(data=newfeature,y=newfeature['storage'])
plt.show()

# %%
newfeature["storage"].value_counts()
# Out:
# 512 GB SSD                                                                                                                                                                                                              575
# 1 TB SSD                                                                                                                                                                                                                154
# 256 GB SSD                                                                                                                                                                                                              123
# 1 TB HDD|256 GB SSD                                                                                                                                                                                                      63
# ...

# %%
# Plotted a countplot for visualizing the value counts of Display size from data

# %%
plt.figure(figsize=(10,6))
sns.countplot(data=newfeature,y=newfeature['display(in inch)'])
plt.show()

# %%
newfeature["display(in inch)"].value_counts()
# Out:
# 15.60    566
# 14.00    215
# 13.30     42
# 16.00     40
# 16.10     27
# 17.30     26
# 13.40     16
# 13.60     12
# 11.60     10
# 14.10      6
# 14.96      5
# 16.20      5
# 15.00      3
# 14.20      2
# 17.00      2
# 35.00      2
# 14.50      1
# 13.50      1
# 16.60      1
# 15.30      1
# 12.00      1
# Name: display(in inch), dtype: int64

# %%
# Plotted a distplot for visualizing the range of price in data

# %%
plt.figure(figsize=(7,7))
sns.distplot(newtarget)
plt.show()

# %%
# Plotted a boxplot for visualizing the outliers present in the data

# %%
plt.figure(figsize=(8,4))
sns.boxplot(data=newfeature,x=newtarget)
plt.grid()
plt.show()

# %%
plt.figure(figsize=(8,4))
sns.boxplot(data=newfeature,x=newtarget,y="brand")
plt.grid()
plt.show()

# %%
newfeature[(newfeature["brand"]=="acer") & (newtarget>200000)]
# Out:
#                               processor               ram  \
# 451  Intel Core i7 Processor (12th Gen)  32 GB LPDDR5 RAM
#
#                                      os   storage  display(in inch) brand
# 451  64 bit Windows 11 Operating System  2 TB SSD              16.0  acer

# %%
newfeature.drop(451,axis=0,inplace=True)
newtarget.drop(451,axis=0,inplace=True)

# %%
newfeature[445:455]
# Out:
#                               processor                       ram  \
# 445  Intel Core i5 Processor (12th Gen)            16 GB DDR4 RAM
# 446  Intel Core i5 Processor (11th Gen)             8 GB DDR4 RAM
# 447              Apple M2 Pro Processor  16 GB Unified Memory RAM
# 448  Intel Core i7 Processor (10th Gen)             8 GB DDR4 RAM
# 449     AMD Ryzen 7 Octa Core Processor            32 GB DDR5 RAM
# 450  Intel Core i5 Processor (11th Gen)             8 GB DDR4 RAM
# 452  Intel Core i9 Processor (12th Gen)            32 GB DDR5 RAM
# 453  Intel Core i5 Processor (12th Gen)             8 GB DDR4 RAM
# 454  Intel Core i7 Processor (12th Gen)            16 GB DDR5 RAM
# 455  Intel Core i5 Processor (11th Gen)             8 GB DDR4 RAM
#
#                                      os     storage  display(in inch)  brand
# 445         Windows 11 Operating System  512 GB SSD              14.0     HP
# 446      64 bit Chrome Operating System  256 GB SSD              14.0     HP
# ...

# %%
plt.figure(figsize=(8,4))
sns.boxplot(data=newfeature,x=newtarget,y="brand")
plt.grid()
plt.show()

# %%
newfeature[(newfeature["brand"]=="Lenovo") & (newtarget>100000)]
# Out:
#                               processor               ram  \
# 86      AMD Ryzen 7 Octa Core Processor    16 GB DDR4 RAM
# 301     AMD Ryzen 7 Octa Core Processor    16 GB DDR4 RAM
# 326     AMD Ryzen 7 Octa Core Processor    32 GB DDR5 RAM
# 366     AMD Ryzen 7 Octa Core Processor    16 GB DDR5 RAM
# 436     AMD Ryzen 7 Octa Core Processor    16 GB DDR5 RAM
# 554     AMD Ryzen 7 Octa Core Processor    32 GB DDR5 RAM
# 582     AMD Ryzen 7 Octa Core Processor    16 GB DDR4 RAM
# 644  Intel Core i7 Processor (12th Gen)    16 GB DDR4 RAM
# 657  Intel Core i7 Processor (11th Gen)    16 GB DDR4 RAM
# 660  Intel Core i7 Processor (11th Gen)    32 GB DDR4 RAM
# 668  Intel Core i7 Processor (12th Gen)     8 GB DDR5 RAM
# 789  Intel Core i7 Processor (12th Gen)  16 GB LPDDR5 RAM
# 849  Intel Core i7 Processor (11th Gen)    16 GB DDR4 RAM
# 863  Intel Core i7 Processor (12th Gen)  16 GB LPDDR5 RAM
# 890   Intel Core i7 Processor (8th Gen)    16 GB DDR4 RAM
# ...

# %%
newfeature.drop([86,301,326,366,436,554,582,644,657,660,668,789,849,863,890,920,924,928,936,946,949],axis=0,inplace=True)
newtarget.drop([86,301,326,366,436,554,582,644,657,660,668,789,849,863,890,920,924,928,936,946,949],axis=0,inplace=True)

# %%
plt.figure(figsize=(8,4))
sns.boxplot(data=newfeature,x=newtarget,y="brand")
plt.grid()
plt.show()

# %%
newfeature[(newfeature["brand"]=="Lenovo") & (newtarget>90000)]
# Out:
#                                      processor             ram  \
# 537  AMD Ryzen 7 Octa Core Processor (5th Gen)  16 GB DDR4 RAM
#
#                                      os     storage  display(in inch)   brand
# 537  64 bit Windows 10 Operating System  512 GB SSD              14.0  Lenovo

# %%
newfeature.drop(537,axis=0,inplace=True)
newtarget.drop(537,axis=0,inplace=True)

# %%
plt.figure(figsize=(8,4))
sns.boxplot(data=newfeature,x=newtarget,y="brand")
plt.grid()
plt.show()

# %%
newfeature[(newfeature["brand"]=="ASUS") & (newtarget>250000)]
# Out:
#                               processor               ram  \
# 262  Intel Core i9 Processor (12th Gen)    32 GB DDR5 RAM
# 431     AMD Ryzen 7 Octa Core Processor  32 GB LPDDR5 RAM
# 434     AMD Ryzen 9 Octa Core Processor    16 GB DDR5 RAM
# 452  Intel Core i9 Processor (12th Gen)    32 GB DDR5 RAM
# 468  Intel Core i9 Processor (12th Gen)  16 GB LPDDR5 RAM
# 492  Intel Core i7 Processor (12th Gen)  16 GB LPDDR5 RAM
# 746     AMD Ryzen 9 Octa Core Processor    32 GB DDR5 RAM
# 753  Intel Core i9 Processor (10th Gen)    32 GB DDR4 RAM
#
#                                      os   storage  display(in inch) brand
# 262  64 bit Windows 11 Operating System  1 TB SSD              15.6  ASUS
# 431  64 bit Windows 11 Operating System  1 TB SSD              13.4  ASUS
# 434         Windows 11 Operating System  1 TB SSD              15.6  ASUS
# 452  64 bit Windows 11 Operating System  4 TB SSD              17.3  ASUS
# ...

# %%
newfeature.drop([262,431,434,452,468,492,746,753],axis=0,inplace=True)
newtarget.drop([262,431,434,452,468,492,746,753],axis=0,inplace=True)

# %%
plt.figure(figsize=(8,4))
sns.boxplot(data=newfeature,x=newtarget,y="brand")
plt.grid()
plt.show()

# %%
newfeature[(newfeature["brand"]=="ASUS") & (newtarget>225000)]
# Out:
#                               processor                ram  \
# 292  Intel Core i9 Processor (12th Gen)     32 GB DDR5 RAM
# 373     AMD Ryzen 7 Octa Core Processor   16 GB LPDDR5 RAM
# 530  Intel Core i7 Processor (10th Gen)   16 GB LPDDR3 RAM
# 552  Intel Core i7 Processor (12th Gen)     32 GB DDR5 RAM
# 623  Intel Core i7 Processor (10th Gen)     32 GB DDR4 RAM
# 646     AMD Ryzen 9 Octa Core Processor  32 GB LPDDR4X RAM
#
#                                      os   storage  display(in inch) brand
# 292  64 bit Windows 11 Operating System  1 TB SSD              15.6  ASUS
# 373  64 bit Windows 11 Operating System  1 TB SSD              13.4  ASUS
# 530  64 bit Windows 10 Operating System  2 TB SSD              14.0  ASUS
# 552  64 bit Windows 11 Operating System  1 TB SSD              16.0  ASUS
# 623  64 bit Windows 10 Operating System  1 TB SSD              15.6  ASUS
# 646  64 bit Windows 10 Operating System  1 TB SSD              13.4  ASUS

# %%
newfeature.drop([292,373,530,552,623,646],axis=0,inplace=True)
newtarget.drop([292,373,530,552,623,646],axis=0,inplace=True)

# %%
plt.figure(figsize=(8,4))
sns.boxplot(data=newfeature,x=newtarget,y="brand")
plt.grid()
plt.show()

# %%
newfeature[(newfeature["brand"]=="ASUS") & (newtarget>200000)]
# Out:
#                               processor             ram  \
# 204     AMD Ryzen 7 Octa Core Processor  32 GB DDR5 RAM
# 449     AMD Ryzen 7 Octa Core Processor  32 GB DDR5 RAM
# 474     AMD Ryzen 9 Octa Core Processor  16 GB DDR5 RAM
# 568  Intel Core i9 Processor (12th Gen)  16 GB DDR5 RAM
# 701   Intel Core i9 Processor (8th Gen)  16 GB DDR4 RAM
#
#                                      os   storage  display(in inch) brand
# 204  64 bit Windows 11 Operating System  2 TB SSD              16.0  ASUS
# 449  64 bit Windows 11 Operating System  2 TB SSD              16.0  ASUS
# 474  64 bit Windows 11 Operating System  1 TB SSD              17.3  ASUS
# 568  64 bit Windows 11 Operating System  1 TB SSD              16.0  ASUS
# 701  64 bit Windows 10 Operating System  1 TB SSD              15.6  ASUS

# %%
newfeature.drop([204,449,474,568,701],axis=0,inplace=True)
newtarget.drop([204,449,474,568,701],axis=0,inplace=True)

# %%
plt.figure(figsize=(8,4))
sns.boxplot(data=newfeature,x=newtarget,y="brand")
plt.grid()
plt.show()

# %%
newfeature[(newfeature["brand"]=="DELL") & (newtarget>120000)]
# Out:
#                               processor             ram  \
# 249  Intel Core i7 Processor (12th Gen)  16 GB DDR5 RAM
# 342  Intel Core i7 Processor (12th Gen)  32 GB DDR5 RAM
# 358  Intel Core i9 Processor (11th Gen)  32 GB DDR4 RAM
# 376     AMD Ryzen 9 Octa Core Processor  16 GB DDR5 RAM
# 405  Intel Core i9 Processor (12th Gen)  16 GB DDR5 RAM
# 475  Intel Core i7 Processor (12th Gen)  16 GB DDR5 RAM
# 524  Intel Core i7 Processor (12th Gen)  32 GB DDR5 RAM
# 526     AMD Ryzen 7 Octa Core Processor  16 GB DDR5 RAM
# 532  Intel Core i7 Processor (12th Gen)  16 GB DDR5 RAM
# 852  Intel Core i9 Processor (10th Gen)  16 GB DDR4 RAM
# 918  Intel Core i7 Processor (12th Gen)  16 GB DDR5 RAM
#
#                                      os     storage  display(in inch) brand
# 249  64 bit Windows 11 Operating System  512 GB SSD              15.6  DELL
# 342  64 bit Windows 11 Operating System    1 TB SSD              17.3  DELL
# ...

# %%
newfeature.drop([249,342,358,376,405,475,524,526,532,852,918],axis=0,inplace=True)
newtarget.drop([249,342,358,376,405,475,524,526,532,852,918],axis=0,inplace=True)

# %%
plt.figure(figsize=(8,4))
sns.boxplot(data=newfeature,x=newtarget,y="brand")
plt.grid()
plt.show()

# %%
newfeature[(newfeature["brand"]=="HP") & (newtarget>150000)]
# Out:
#                               processor               ram  \
# 241  Intel Core i7 Processor (12th Gen)    16 GB DDR5 RAM
# 314  Intel Core i9 Processor (12th Gen)    32 GB DDR5 RAM
# 341  Intel Core i7 Processor (12th Gen)    32 GB DDR5 RAM
# 441  Intel Core i7 Processor (12th Gen)    16 GB DDR5 RAM
# 605  Intel Core i7 Processor (12th Gen)    16 GB DDR5 RAM
# 606  Intel Core i7 Processor (12th Gen)    16 GB DDR5 RAM
# 735     AMD Ryzen 9 Octa Core Processor    32 GB DDR5 RAM
# 855  Intel Core i7 Processor (10th Gen)  16 GB LPDDR3 RAM
# 892  Intel Core i7 Processor (10th Gen)    16 GB DDR4 RAM
# 903  Intel Core i7 Processor (11th Gen)    16 GB DDR4 RAM
#
#                                      os     storage  display(in inch) brand
# 241  64 bit Windows 11 Operating System    1 TB SSD              16.1    HP
# 314  64 bit Windows 11 Operating System    2 TB SSD              17.3    HP
# 341  64 bit Windows 11 Operating System    1 TB SSD              17.3    HP
# ...

# %%
newfeature.drop([241,314,341,441,605,606,735,855,892,903],axis=0,inplace=True)
newtarget.drop([241,314,341,441,605,606,735,855,892,903],axis=0,inplace=True)

# %%
plt.figure(figsize=(8,4))
sns.boxplot(data=newfeature,x=newtarget,y="brand")
plt.grid()
plt.show()

# %%
newfeature[(newfeature["brand"]=="MSI") & (newtarget>350000)]
# Out:
#                               processor             ram  \
# 72   Intel Core i9 Processor (13th Gen)  32 GB DDR5 RAM
# 966  Intel Core i9 Processor (12th Gen)  32 GB DDR5 RAM
#
#                                      os   storage  display(in inch) brand
# 72          Windows 11 Operating System  2 TB SSD              17.0   MSI
# 966  64 bit Windows 11 Operating System  2 TB SSD              15.6   MSI

# %%
newfeature.drop([72,966],axis=0,inplace=True)
newtarget.drop([72,966],axis=0,inplace=True)

# %%
plt.figure(figsize=(8,4))
sns.boxplot(data=newfeature,x=newtarget,y="brand")
plt.grid()
plt.show()

# %%
newfeature[(newfeature["brand"]=="Avita") & (newtarget>40000)]
# Out:
#                               processor             ram  \
# 974  Intel Core i7 Processor (10th Gen)  16 GB DDR4 RAM
#
#                                      os   storage  display(in inch)  brand
# 974  64 bit Windows 10 Operating System  1 TB SSD              14.0  Avita

# %%
newfeature.drop([974],axis=0,inplace=True)
newtarget.drop([974],axis=0,inplace=True)

# %%
plt.figure(figsize=(8,4))
sns.boxplot(data=newfeature,x=newtarget,y="brand")
plt.grid()
plt.show()

# %%
newfeature[(newfeature["brand"]=="MSI") & (newtarget>285000)]
# Out:
#                               processor             ram  \
# 115  Intel Core i9 Processor (12th Gen)  32 GB DDR5 RAM
#
#                                      os   storage  display(in inch) brand
# 115  64 bit Windows 11 Operating System  2 TB SSD              17.3   MSI

# %%
newfeature.drop([115],axis=0,inplace=True)
newtarget.drop([115],axis=0,inplace=True)

# %%
plt.figure(figsize=(8,4))
sns.boxplot(data=newfeature,x=newtarget,y="brand")
plt.grid()
plt.show()

# %%
newfeature[(newfeature["brand"]=="ASUS") & (newtarget>190000)]
# Out:
#                               processor               ram  \
# 281     AMD Ryzen 9 Octa Core Processor    32 GB DDR5 RAM
# 688  Intel Core i9 Processor (12th Gen)  16 GB LPDDR5 RAM
#
#                                      os   storage  display(in inch) brand
# 281  64 bit Windows 11 Operating System  1 TB SSD              14.0  ASUS
# 688  64 bit Windows 11 Operating System  1 TB SSD              13.4  ASUS

# %%
newfeature.drop([281,688],axis=0,inplace=True)
newtarget.drop([281,688],axis=0,inplace=True)

# %%
plt.figure(figsize=(8,4))
sns.boxplot(data=newfeature,x=newtarget,y="brand")
plt.grid()
plt.show()

# %%
newfeature[(newfeature["brand"]=="ASUS") & (newtarget>185000)]
# Out:
#                            processor             ram  \
# 792  AMD Ryzen 7 Octa Core Processor  16 GB DDR5 RAM
# 882  AMD Ryzen 7 Octa Core Processor  16 GB DDR5 RAM
# 906  AMD Ryzen 9 Octa Core Processor  16 GB DDR5 RAM
# 957  AMD Ryzen 9 Octa Core Processor  16 GB DDR4 RAM
#
#                                      os   storage  display(in inch) brand
# 792         Windows 11 Operating System  1 TB SSD              15.6  ASUS
# 882         Windows 11 Operating System  1 TB SSD              16.0  ASUS
# 906  64 bit Windows 11 Operating System  1 TB SSD              15.6  ASUS
# 957  64 bit Windows 11 Operating System  1 TB SSD              15.6  ASUS

# %%
newfeature.drop([792,882,906,957],axis=0,inplace=True)
newtarget.drop([792,882,906,957],axis=0,inplace=True)

# %%
plt.figure(figsize=(8,4))
sns.boxplot(data=newfeature,x=newtarget,y="brand")
plt.grid()
plt.show()

# %%
newfeature[(newfeature["brand"]=="ASUS") & (newtarget>152000)]
# Out:
#                               processor               ram  \
# 54   Intel Core i9 Processor (12th Gen)  32 GB LPDDR5 RAM
# 145     AMD Ryzen 9 Octa Core Processor    16 GB DDR5 RAM
# 248     AMD Ryzen 9 Octa Core Processor    16 GB DDR4 RAM
# 296     AMD Ryzen 9 Octa Core Processor    16 GB DDR5 RAM
# 304     AMD Ryzen 9 Octa Core Processor    16 GB DDR4 RAM
# 374  Intel Core i9 Processor (12th Gen)  16 GB LPDDR5 RAM
# 403     AMD Ryzen 7 Octa Core Processor    16 GB DDR5 RAM
# 425     AMD Ryzen 7 Octa Core Processor    16 GB DDR5 RAM
# 430     AMD Ryzen 7 Octa Core Processor    16 GB DDR5 RAM
# 456     AMD Ryzen 9 Octa Core Processor    16 GB DDR4 RAM
# 538     AMD Ryzen 7 Octa Core Processor    16 GB DDR5 RAM
# 609  Intel Core i7 Processor (10th Gen)  16 GB LPDDR3 RAM
# 637     AMD Ryzen 7 Octa Core Processor  32 GB LPDDR5 RAM
# 647     AMD Ryzen 7 Octa Core Processor    16 GB DDR5 RAM
# 737  Intel Core i7 Processor (12th Gen)    16 GB DDR5 RAM
# ...

# %%
newfeature.drop([296,403,456,647,737],axis=0,inplace=True)
newtarget.drop([296,403,456,647,737],axis=0,inplace=True)

# %%
plt.figure(figsize=(8,4))
sns.boxplot(data=newfeature,x=newtarget,y="brand")
plt.grid()
plt.show()

# %% [markdown]
# # Label Encoding

# %%
# Loop over each column in the DataFrame where dtype is 'object'
for col in newfeature.select_dtypes(include=['object']).columns:
    
    #  print the column name and the unique values
    print(f'{col}: {newfeature[col].unique()}')
# Out:
# processor: ['Intel Core i5 Processor (11th Gen)' 'Intel Core i3 Processor (11th Gen)'
#  'Intel Core i5 Processor (10th Gen)' 'Intel Core i3 Processor (10th Gen)'
#  'AMD Athlon Dual Core Processor' 'Apple M1 Processor'
#  'Intel Celeron Dual Core Processor' 'AMD Ryzen 3 Quad Core Processor'
#  'AMD Ryzen 3 Dual Core Processor' 'Intel Core i5 Processor (12th Gen)'
#  'Intel Core i7 Processor (11th Gen)' 'AMD Ryzen 5 Hexa Core Processor'
#  'Intel Core i3 Processor (12th Gen)' 'AMD Ryzen 7 Octa Core Processor'
#  'Qualcomm Snapdragon 7c Gen 2 Processor'
#  'Intel Core i7 Processor (12th Gen)' 'Intel Pentium Silver Processor'
#  'AMD Ryzen 5 Quad Core Processor' 'Apple M2 Processor'
#  'Intel Core i9 Processor (12th Gen)' 'Intel Core i7 Processor (13th Gen)'
#  'AMD Dual Core Processor' 'AMD Ryzen 9 Octa Core Processor'
#  'Apple M1 Max Processor' 'Apple M1 Pro Processor'
#  'Apple M2 Pro Processor' 'Intel Pentium Quad Core Processor'
#  'Intel Core i7 Processor (10th Gen)'
# ...

# %% [markdown]
# # Segmentation of the Company's

# %%
def segment_company(company):
    return company.split()[0]
    
    if pd.isnull(Company):
        return 'Unknown'
    elif 'Lenovo' in company:
        return 'Lenovo'
    elif 'HP' in company:
        return 'HP'
    elif 'DELL' in company:
        return 'DELL'
    elif 'ASUS' in company:
        return 'ASUS'
    elif 'MSI' in company:
        return 'MSI'
    elif 'APPLE' in company:
        return 'APPLE'
    else:
        return 'Other'
    
newfeature['brand'] =newfeature['brand'].apply(segment_company)

# %%
plt.figure(figsize=(10,4))
newfeature['brand'].value_counts().plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Segmentation of the Processor

# %%
newfeature['processor'].unique()
# Out:
# array(['Intel Core i5 Processor (11th Gen)',
#        'Intel Core i3 Processor (11th Gen)',
#        'Intel Core i5 Processor (10th Gen)',
#        'Intel Core i3 Processor (10th Gen)',
#        'AMD Athlon Dual Core Processor', 'Apple M1 Processor',
#        'Intel Celeron Dual Core Processor',
#        'AMD Ryzen 3 Quad Core Processor',
#        'AMD Ryzen 3 Dual Core Processor',
#        'Intel Core i5 Processor (12th Gen)',
#        'Intel Core i7 Processor (11th Gen)',
#        'AMD Ryzen 5 Hexa Core Processor',
#        'Intel Core i3 Processor (12th Gen)',
#        'AMD Ryzen 7 Octa Core Processor',
#        'Qualcomm Snapdragon 7c Gen 2 Processor',
#        'Intel Core i7 Processor (12th Gen)',
#        'Intel Pentium Silver Processor',
#        'AMD Ryzen 5 Quad Core Processor', 'Apple M2 Processor',
#        'Intel Core i9 Processor (12th Gen)',
#        'Intel Core i7 Processor (13th Gen)', 'AMD Dual Core Processor',
# ...

# %%
def segment_processor(processor):
    if pd.isnull(processor):
        return 'Unknown'
    
    elif 'Intel Core i5 Processor (11th Gen)' in processor:
        return 'Intel i5 11 Gen '
    elif 'Intel Core i3 Processor (11th Gen)' in processor:
        return 'Intel i3 11 gen'
    elif 'Intel Core i5 Processor (10th Gen)' in processor:
        return 'Intel i5 10 gen'
    elif 'Intel Core i3 Processor (10th Gen)' in processor:
        return 'Intel i3 10 gen'
    elif 'Intel Core i5 Processor (12th Gen)' in processor:
        return 'Intel i5 12 gen'
    elif 'Intel Core i3 Processor (12th Gen)' in processor:
        return 'Intel i3 12 gen'
    elif 'Intel Core i7 Processor (12th Gen)' in processor:
        return 'Intel i7 12 gen'
    elif 'Intel Core i7 Processor (13th Gen)' in processor:
        return 'Intel i9 13 gen'
    elif 'Intel Core i9 Processor (12th Gen)' in processor:
        return 'Intel i9 12 gen'
    elif 'Apple M1 Processor' in processor or 'Apple M1 Pro Processor' in processor:
        return 'Apple M1'
    elif 'Apple M2 Processor' in processor or 'Apple M2 Processor' in processor:
        return 'Apple M2'
    elif 'AMD Ryzen 7 Hexa Core Processor' in processor:
        return 'AMD Ryzen 7'
    elif 'AMD Ryzen 9 Octa Core Processor (10th Gen)' in processor:
        return 'AMD Ryzen 9'
    elif 'AMD Ryzen 5 Hexa Core Processor (10th Gen' in processor:
        return 'AMD Ryzen 5'
    elif 'AMD Ryzen 3 Quad Core Processor' in processor:
        return 'AMD Ryzen 3'
    else:
        return 'Others'
    
    
newfeature['processor'] = newfeature['processor'].apply(segment_processor)

# %%
plt.figure(figsize=(10,4))
newfeature['processor'].value_counts().plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Segmentation of the RAM

# %%
newfeature['ram'].unique()
# Out:
# array(['16 GB DDR4 RAM', '8 GB DDR4 RAM', '4 GB DDR4 RAM',
#        '16 GB LPDDR5 RAM', '16 GB DDR5 RAM', '4 GB LPDDR4X RAM',
#        '8 GB LPDDR4X RAM', '8 GB Unified Memory RAM', '32 GB LPDDR5 RAM',
#        '4 GB LPDDR4 RAM', '16 GB LPDDR4X RAM', '8 GB DDR5 RAM',
#        '32 GB DDR5 RAM', '32 GB Unified Memory RAM',
#        '16 GB Unified Memory RAM', '16 GB LPDDR4 RAM', '32 GB DDR4 RAM',
#        '8 GB DDR3 RAM', '8 GB LPDDR3 RAM', '16 GB LPDDR3 RAM',
#        '16 GB DDR3 RAM'], dtype=object)

# %%
def segment_ram(ram):
    if pd.isnull(ram):
        return 'Unknown'
    elif '4 GB DDR4 RAM' in ram or '4 GB LPDDR4X RAM' in ram or '4 GB LPDDR4 RAM' in ram:
        return '4 GB RAM'
    elif '8 GB DDR4 RAM' in ram or '8 GB LPDDR4X RAM' in ram or '8 GB Unified Memory RAM' in ram or '8 GB DDR5 RAM' in ram or '8 GB DDR3 RAM' in ram or '8 GB LPDDR3 RAM' in ram :
        return '8 GB RAM'
    elif '16 GB DDR4 RAM' in ram or '16 GB LPDDR5 RAM' in ram or '16 GB DDR5 RAM' in ram or '16 GB LPDDR4X RAM' or '16 GB Unified Memory RAM' in ram or '16 GB LPDDR4 RAM' in ram or '16 GB LPDDR3 RAM' in ram or '16 GB DDR3 RAM' in ram:
        return '16 GB RAM'
    elif '32 GB DDR5 RAM' in ram or '32 GB Unified Memory RAM' in ram or '32 GB DDR4 RAM' in ram or '32 GB LPDDR4X RAM' in ram:
        return '32 GB RAM'
    else:
        return 'Others'
    
    
newfeature['ram'] = newfeature['ram'].apply(segment_ram)

# %%
plt.figure(figsize=(10,4))
newfeature['ram'].value_counts().plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Segmentation of the Operating system

# %%
newfeature ['os'].unique()
# Out:
# array(['Windows 11 Operating System',
#        '64 bit Windows 11 Operating System', 'DOS Operating System',
#        'Mac OS Operating System', '64 bit Windows 10 Operating System',
#        '32 bit Windows 11 Operating System', 'Chrome Operating System',
#        '64 bit Chrome Operating System', 'Windows 10 Operating System',
#        '64 bit DOS Operating System', '64 bit Windows 8 Operating System'],
#       dtype=object)

# %%
def segment_os(os):
    if pd.isnull(os):
        return 'Unknown'
    elif 'Windows 11 Operating System' in os:
        return 'Windows 11'
    elif '64 bit Windows 11 Operating System' in os:
        return '64-bit Windows 11'
    elif 'Mac OS Operating System' in os:
        return 'Mac OS'
    elif 'Windows 10 Operating System' in os:
        return 'Windows 10'
    elif 'DOS Operating System' in os:
        return 'DOS OS'
    else:
        return 'Other'
    
    
newfeature['os'] = newfeature['os'].apply(segment_os)

# %%
plt.figure(figsize=(10,4))
newfeature['os'].value_counts().plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Segmentation of the STORAGE

# %%
newfeature['storage'].unique()
# Out:
# array(['512 GB SSD', '1 TB HDD|256 GB SSD', '256 GB SSD', '1 TB SSD',
#        '2 TB SSD', '1 TB HDD|512 GB SSD', '1 TB HDD', '128 GB SSD',
#        '256 GB HDD|256 GB SSD', '512 GB HDD|512 GB SSD',
#        '1 TB HDD|128 GB SSD',
#        'PCI-e SSD (NVMe) ready,Silver-Lining Print Keyboard,Matrix Display (Extend),Cooler Boost 5,Hi-Res Audio,Nahimic 3,144Hz Panel,Thin Bezel,RGB Gaming Keyboard,Speaker Tuning Engine,MSI Center',
#        'PCI-e Gen4 SSD?SHIFT?Matrix Display (Extend)?Cooler Boost 3?Thunderbolt 4?Finger Print Security?True Color 2.0?Hi-Res Audio?Nahimic 3? 4-Sided Thin bezel?MSI Center?Silky Smooth Touchpad?Military-Grade Durability',
#        '2 TB HDD', '256 GB HDD'], dtype=object)

# %%
def segment_storage(storage):
    if pd.isnull(storage):
        return 'Unknown'
    elif '512 GB SSD' in storage:
        return '512 GB SSD'
    elif '256 GB SSD' in storage:
        return '256 GB SSD'
    elif '4 TB SSD' in storage:
        return '4 TB SSD'
    elif '2 TB SSD' in storage:
        return '2 TB SSD'
    elif '1 TB SSD' in storage:
        return '1 TB SSD'
    elif '1 TB HDD|512 GB SSD' in storage:
        return '1 TB HDD|512 GB SSD'
    elif '2 TB HDD' in storage:
        return '2 TB HDD'
    else:
        return 'Other'
    
newfeature['storage'] = newfeature['storage'].apply(segment_storage)

# %%
plt.figure(figsize=(10,4))
newfeature['storage'].value_counts().plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Relation between Price and Brand of laptop

# %%
plt.figure(figsize=(8,8))
sns.scatterplot(data=df,x=newtarget,y=newfeature["brand"])
plt.show()

# %% [markdown]
# # Relation between Price and Processor of laptop

# %%
plt.figure(figsize=(8,8))
sns.scatterplot(data=df,x=newtarget,y=newfeature["processor"])
plt.show()

# %% [markdown]
# # Relation between Price and Ram of laptop

# %%
plt.figure(figsize=(8,8))
sns.scatterplot(data=df,x=newtarget,y=newfeature["ram"])
plt.show()

# %% [markdown]
# # Relation between Price and Operating system of laptop

# %%
plt.figure(figsize=(8,8))
sns.scatterplot(data=df,x=newtarget,y=newfeature["os"])
plt.show()

# %% [markdown]
# # Relation between Price and Storage of laptop

# %%
plt.figure(figsize=(8,8))
sns.scatterplot(data=df,x=newtarget,y=newfeature["storage"])
plt.show()

# %% [markdown]
# # Label Encoding of Object Datatypes

# %%
# Loop over each column in the DataFrame where dtype is 'object'
for col in newfeature.select_dtypes(include=['object']).columns:
    
    #  print the column name and the unique values
    print(f'{col}: {newfeature[col].unique()}')
# Out:
# processor: ['Intel i5 11 Gen ' 'Intel i3 11 gen' 'Intel i5 10 gen' 'Intel i3 10 gen'
#  'Others' 'Apple M1' 'AMD Ryzen 3' 'Intel i5 12 gen' 'Intel i3 12 gen'
#  'Intel i7 12 gen' 'Apple M2' 'Intel i9 12 gen' 'Intel i9 13 gen'
#  'AMD Ryzen 7' 'AMD Ryzen 5' 'AMD Ryzen 9']
# ram: ['16 GB RAM' '8 GB RAM' '4 GB RAM']
# os: ['Windows 11' 'DOS OS' 'Mac OS' 'Windows 10' 'Other']
# storage: ['512 GB SSD' '256 GB SSD' '1 TB SSD' '2 TB SSD' 'Other' '2 TB HDD']
# brand: ['Lenovo' 'ASUS' 'APPLE' 'DELL' 'RedmiBook' 'acer' 'realme' 'HP' 'MSI'
#  'SAMSUNG' 'Infinix' 'ALIENWARE' 'GIGABYTE' 'Avita' 'Mi' 'MICROSOFT' 'LG'
#  'lenovo' 'Vaio' 'Ultimus' 'Nokia']

# %%
from sklearn import preprocessing

# Loop over each column in the the DataFrame where dtype is 'object '
for col in newfeature.select_dtypes(include=['object']).columns:
    
    # Initialize a LabelEncoder object
    label_encoder = preprocessing.LabelEncoder()
    
    # Fit the encoder to the unique values in the column
    label_encoder.fit(newfeature[col].unique())
    
    # Transform the column using the encoder
    newfeature[col] = label_encoder.transform(newfeature[col])
    
    # print the columns name and the unique encoded values
    print(f'{col}: {newfeature[col].unique()}')
# Out:
# processor: [10  7  9  6 15  4  0 11  8 12  5 13 14  2  1  3]
# ram: [0 2 1]
# os: [4 0 1 3 2]
# storage: [4 3 0 2 5 1]
# brand: [ 9  2  1  4 14 18 20  6 11 15  7  0  5  3 12 10  8 19 17 16 13]

# %%
newfeature
# Out:
#      processor  ram  os  storage  display(in inch)  brand
# 0           10    0   4        4              15.6      9
# 1            7    2   4        3              15.6      9
# 2            9    2   4        4              15.6      2
# 3            6    2   4        4              15.6      2
# 4           15    1   0        3              14.0      9
# ..         ...  ...  ..      ...               ...    ...
# 979          6    2   3        5              15.6      2
# 980         15    1   2        5              11.6      6
# 981         15    2   4        4              14.0      2
# 982          7    2   4        3              15.6      4
# 983         15    1   4        3              14.0      2
#
# [906 rows x 6 columns]

# %% [markdown]
# # Scaling of the Data

# %%
from sklearn.preprocessing import StandardScaler
ss = StandardScaler()
newfeature.iloc[:,:] = ss.fit_transform(newfeature.iloc[:,:])

# %% [markdown]
# # Correlation Heatmap

# %%
plt.figure(figsize=(8,4))
sns.heatmap(newfeature.corr(), annot = True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Train Test Split

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(newfeature,newtarget,test_size=0.3,random_state=20)

# %%
X_train
# Out:
#      processor       ram        os   storage  display(in inch)     brand
# 602  -0.960846  0.837980 -0.758017 -0.298657          0.354705 -0.552106
# 800   0.023634  0.837980  0.513767  0.470046         -0.839398 -0.106685
# 880   1.008114  0.837980  0.513767  0.470046          1.623440 -0.997528
# 90    0.269754 -1.288658  0.513767  0.470046         -0.839398 -0.106685
# 139  -0.960846  0.837980  0.513767 -0.298657          0.354705 -0.552106
# ..         ...       ...       ...       ...               ...       ...
# 222  -0.222486 -1.288658  0.513767  0.470046          0.354705 -0.552106
# 227  -0.960846  0.837980  0.513767  0.470046          0.354705  0.561447
# 278   1.008114 -1.288658  0.513767 -2.604768          0.354705  1.006869
# 507  -0.960846  0.837980  0.513767  0.470046          0.354705  0.561447
# 372  -0.714726  0.837980  0.513767 -0.298657         -0.839398 -0.552106
#
# [634 rows x 6 columns]

# %%
X_test
# Out:
#      processor       ram        os   storage  display(in inch)     brand
# 686  -0.960846  0.837980  0.513767  0.470046         -0.839398 -0.997528
# 857   1.008114  0.837980 -0.758017  0.470046          0.354705 -0.997528
# 413   0.269754 -1.288658  0.513767  0.470046          0.653231 -0.106685
# 123  -0.222486 -1.288658  0.513767  0.470046          0.354705  0.561447
# 624   1.008114 -1.288658  0.513767  0.470046          0.727862 -0.106685
# ..         ...       ...       ...       ...               ...       ...
# 78    1.008114 -1.288658  0.513767  0.470046          0.653231 -0.997528
# 517   1.008114 -0.225339  0.513767  1.238750         -2.630552 -0.997528
# 226   1.008114  0.837980  0.513767  0.470046          0.354705 -0.997528
# 705  -0.222486  0.837980  0.513767  0.470046          0.354705  0.116026
# 865  -0.222486  0.837980 -0.758017  1.238750          0.354705  2.565844
#
# [272 rows x 6 columns]

# %%
y_train
# Out:
# 602     40890
# 800     62990
# 880     72990
# 90      91990
# 139     42490
#         ...
# 222     72990
# 227     38699
# 278    129990
# 507     38500
# 372     56749
# Name: price(in Rs.), Length: 634, dtype: int64

# %%
y_test
# Out:
# 686     41990
# 857     65990
# 413    145499
# 123     62990
# 624     85990
#         ...
# 78      54990
# 517     24290
# 226     34990
# 705     42990
# 865     47130
# Name: price(in Rs.), Length: 272, dtype: int64

# %% [markdown]
# # Model Evaluation

# %%
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor

# %%
linreg = LinearRegression()
knn = KNeighborsRegressor()
svm = SVR()
dt = DecisionTreeRegressor()

# %%
from sklearn.metrics import r2_score

# %%
def mymodel(model):
    model.fit(X_train,y_train)
    y_pred = model.predict(X_test)
    
    train = model.score(X_train,y_train)
    test = model.score(X_test,y_test)
    
    print(f"Training score : {train}")
    print(f"Testing score  : {test}")
    
    print("Accuracy of model is :",r2_score(y_test,y_pred))
    
    return model

# %%
mymodel(linreg)
# Out:
# Training score : 0.529804310630118
# Testing score  : 0.4869504584191804
# Accuracy of model is : 0.4869504584191804
# LinearRegression()

# %%
mymodel(knn)
# Out:
# Training score : 0.7969013921545667
# Testing score  : 0.6747474452609317
# Accuracy of model is : 0.6747474452609317
# KNeighborsRegressor()

# %%
mymodel(svm)
# Out:
# Training score : -0.06547311494331876
# Testing score  : -0.040378017079572226
# Accuracy of model is : -0.040378017079572226
# SVR()

# %%
mymodel(dt)
# Out:
# Training score : 0.9303567792878586
# Testing score  : 0.791934953145101
# Accuracy of model is : 0.791934953145101
# DecisionTreeRegressor()

# %%
from sklearn.model_selection import GridSearchCV

# %%
param = {"max_depth":[1,100],"min_samples_split":[2,100],"min_samples_leaf":[1,100]}

# %%
gs = GridSearchCV(dt,param,verbose=3)
gs.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# [CV 1/5] END max_depth=1, min_samples_leaf=1, min_samples_split=2;, score=0.544 total time=   0.0s
# [CV 2/5] END max_depth=1, min_samples_leaf=1, min_samples_split=2;, score=0.369 total time=   0.0s
# [CV 3/5] END max_depth=1, min_samples_leaf=1, min_samples_split=2;, score=0.393 total time=   0.0s
# [CV 4/5] END max_depth=1, min_samples_leaf=1, min_samples_split=2;, score=0.307 total time=   0.0s
# [CV 5/5] END max_depth=1, min_samples_leaf=1, min_samples_split=2;, score=0.284 total time=   0.0s
# [CV 1/5] END max_depth=1, min_samples_leaf=1, min_samples_split=100;, score=0.544 total time=   0.0s
# [CV 2/5] END max_depth=1, min_samples_leaf=1, min_samples_split=100;, score=0.369 total time=   0.0s
# [CV 3/5] END max_depth=1, min_samples_leaf=1, min_samples_split=100;, score=0.393 total time=   0.0s
# [CV 4/5] END max_depth=1, min_samples_leaf=1, min_samples_split=100;, score=0.307 total time=   0.0s
# ...

# %%
gs.best_params_
# Out:
# {'max_depth': 100, 'min_samples_leaf': 1, 'min_samples_split': 2}

# %%
dtf = DecisionTreeRegressor(max_depth=100,min_samples_split=2,min_samples_leaf=1)

# %%
mymodel(dtf)
# Out:
# Training score : 0.9303567792878586
# Testing score  : 0.7988447468973937
# Accuracy of model is : 0.7988447468973937
# DecisionTreeRegressor(max_depth=100)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf = RandomForestRegressor()
rf.fit(X_train,y_train)
y_pred = rf.predict(X_test)

train = rf.score(X_train,y_train)
test = rf.score(X_test,y_test)

print(f"traing score {train}")
print(f"testing score {test}")

print("Accuracy of model is :",r2_score(y_test,y_pred))
# Out:
# traing score 0.9173508314178775
# testing score 0.8263697574041311
# Accuracy of model is : 0.8263697574041311

# %%
param = {"max_depth":[1,1000],"min_samples_split":[2,1000],"min_samples_leaf":[1,1000]}

# %%
gs = GridSearchCV(rf,param,verbose=3)
gs.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# [CV 1/5] END max_depth=1, min_samples_leaf=1, min_samples_split=2;, score=0.559 total time=   0.0s
# [CV 2/5] END max_depth=1, min_samples_leaf=1, min_samples_split=2;, score=0.380 total time=   0.1s
# [CV 3/5] END max_depth=1, min_samples_leaf=1, min_samples_split=2;, score=0.400 total time=   0.1s
# [CV 4/5] END max_depth=1, min_samples_leaf=1, min_samples_split=2;, score=0.303 total time=   0.1s
# [CV 5/5] END max_depth=1, min_samples_leaf=1, min_samples_split=2;, score=0.292 total time=   0.1s
# [CV 1/5] END max_depth=1, min_samples_leaf=1, min_samples_split=1000;, score=-0.022 total time=   0.1s
# [CV 2/5] END max_depth=1, min_samples_leaf=1, min_samples_split=1000;, score=-0.002 total time=   0.1s
# [CV 3/5] END max_depth=1, min_samples_leaf=1, min_samples_split=1000;, score=-0.025 total time=   0.1s
# [CV 4/5] END max_depth=1, min_samples_leaf=1, min_samples_split=1000;, score=-0.000 total time=   0.0s
# ...

# %%
gs.best_params_
# Out:
# {'max_depth': 1000, 'min_samples_leaf': 1, 'min_samples_split': 2}

# %%
rft = RandomForestRegressor(max_depth=1000,min_samples_split=2,min_samples_leaf=1)

# %%
mymodel(rft)
# Out:
# Training score : 0.9161139726800762
# Testing score  : 0.8282646105935907
# Accuracy of model is : 0.8282646105935907
# RandomForestRegressor(max_depth=1000)

# %% [markdown]
# # Bagging

# %%
from sklearn.ensemble import BaggingRegressor

# %%
br = BaggingRegressor(linreg)
br.fit(X_train,y_train)
y_pred = br.predict(X_test)

train = br.score(X_train,y_train)
test = br.score(X_test,y_test)

print(f"Traing score is : {train}")
print(f"Testing score is : {test}")

print(f"Accuracy score is : {r2_score(y_test,y_pred)}")
# Out:
# Traing score is : 0.5284164831134661
# Testing score is : 0.49279673078680375
# Accuracy score is : 0.49279673078680375

# %%
br = BaggingRegressor(knn)
br.fit(X_train,y_train)
y_pred = br.predict(X_test)

train = br.score(X_train,y_train)
test = br.score(X_test,y_test)

print(f"Traing score is : {train}")
print(f"Testing score is : {test}")

print(f"Accuracy score is : {r2_score(y_test,y_pred)}")
# Out:
# Traing score is : 0.7876039138204648
# Testing score is : 0.6556781403335518
# Accuracy score is : 0.6556781403335518

# %%
br = BaggingRegressor(svm)
br.fit(X_train,y_train)
y_pred = br.predict(X_test)

train = br.score(X_train,y_train)
test = br.score(X_test,y_test)

print(f"Traing score is : {train}")
print(f"Testing score is : {test}")

print(f"Accuracy score is : {r2_score(y_test,y_pred)}")
# Out:
# Traing score is : -0.05434857735834275
# Testing score is : -0.0310906299482967
# Accuracy score is : -0.0310906299482967

# %%
br = BaggingRegressor(dt)
br.fit(X_train,y_train)
y_pred = br.predict(X_test)

train = br.score(X_train,y_train)
test = br.score(X_test,y_test)

print(f"Traing score is : {train}")
print(f"Testing score is : {test}")

print(f"Accuracy score is : {r2_score(y_test,y_pred)}")
# Out:
# Traing score is : 0.9076554447953935
# Testing score is : 0.7976128814369637
# Accuracy score is : 0.7976128814369637

# %%
br = BaggingRegressor(dtf)
br.fit(X_train,y_train)
y_pred = br.predict(X_test)

train = br.score(X_train,y_train)
test = br.score(X_test,y_test)

print(f"Traing score is : {train}")
print(f"Testing score is : {test}")

print(f"Accuracy score is : {r2_score(y_test,y_pred)}")
# Out:
# Traing score is : 0.9115831108070226
# Testing score is : 0.8341102161978629
# Accuracy score is : 0.8341102161978629

# %% [markdown]
# # Voting

# %%
from sklearn.ensemble import VotingRegressor

# %%
model = []

model.append(("Linear Regression",LinearRegression()))
model.append(("KNN regressor",KNeighborsRegressor()))
model.append(("Support vector machine",SVR()))
model.append(("Decision Tree Regressor",DecisionTreeRegressor()))

# %%
model
# Out:
# [('Linear Regression', LinearRegression()),
#  ('KNN regressor', KNeighborsRegressor()),
#  ('Support vector machine', SVR()),
#  ('Decision Tree Regressor', DecisionTreeRegressor())]

# %% [markdown]
# # Hard Voting

# %%
vr = VotingRegressor(model)
vr.fit(X_train,y_train)
y_pred = vr.predict(X_test)

train = vr.score(X_train,y_train)
test = vr.score(X_test,y_test)

print(f"Traing score is : {train}")
print(f"Testing score is : {test}")

print(f"Accuracy score is : {r2_score(y_test,y_pred)}")
# Out:
# Traing score is : 0.7453019015520786
# Testing score is : 0.6792624629084504
# Accuracy score is : 0.6792624629084504

# %% [markdown]
# # Soft Voting

# %%
model = []

model.append(("Linear Regression",LinearRegression()))
model.append(("KNN regressor",KNeighborsRegressor()))

model.append(("Decision Tree Regressor",DecisionTreeRegressor()))

# %%
vr = VotingRegressor(model,)
vr.fit(X_train,y_train)
y_pred = vr.predict(X_test)

train = vr.score(X_train,y_train)
test = vr.score(X_test,y_test)

print(f"Traing score is : {train}")
print(f"Testing score is : {test}")

print(f"Accuracy score is : {r2_score(y_test,y_pred)}")
# Out:
# Traing score is : 0.8383402355891175
# Testing score is : 0.7589660244435656
# Accuracy score is : 0.7589660244435656

# %% [markdown]
# # Boosting

# %%
from sklearn.ensemble import AdaBoostRegressor

# %%
abr = AdaBoostRegressor()
abr.fit(X_train,y_train)
y_pred = abr.predict(X_test)

train = abr.score(X_train,y_train)
test = abr.score(X_test,y_test)

print(f"Traings score is : {train}")
print(f"Testings score is : {test}")

print(f"Accuracy score is : {r2_score(y_test,y_pred)}")
# Out:
# Traings score is : 0.7044070825010518
# Testings score is : 0.648544312532831
# Accuracy score is : 0.648544312532831

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
gbr = GradientBoostingRegressor()
gbr.fit(X_train,y_train)
y_pred = gbr.predict(X_test)

train = gbr.score(X_train,y_train)
test = gbr.score(X_test,y_test)

print(f"Traning score is : {train}")
print(f"Testing score is : {test}")

print(f"Accuracy score is : {r2_score(y_test,y_pred)}")
# Out:
# Traning score is : 0.8712610790252777
# Testing score is : 0.8416200416746529
# Accuracy score is : 0.8416200416746529

# %%
from xgboost import XGBRegressor

# %%
xg = XGBRegressor()
xg.fit(X_train,y_train)
y_pred = xg.predict(X_test)

train = xg.score(X_train,y_train)
test = xg.score(X_test,y_test)

print(f"Traning score is : {train}")
print(f"Testing score is : {test}")

print(f"Accuracy score is : {r2_score(y_test,y_pred)}")
# Out:
# Traning score is : 0.9281371030518122
# Testing score is : 0.8100408746659584
# Accuracy score is : 0.8100408746659584

# %% [markdown]
# # Best Model for this Data

# %%
gbr = GradientBoostingRegressor()
gbr.fit(X_train,y_train)
y_pred = gbr.predict(X_test)

train = gbr.score(X_train,y_train)
test = gbr.score(X_test,y_test)

print(f"Traning score is : {train}")
print(f"Testing score is : {test}")

print(f"Accuracy score is : {r2_score(y_test,y_pred)}")
# Out:
# Traning score is : 0.8712610790252777
# Testing score is : 0.8417835436377195
# Accuracy score is : 0.8417835436377195

# %% [markdown]
# # Funtion for prediction

# %%
def price_predicts():
    print('*'*100)
    print('Laptops Name')
    print(
        '''
       for Lenovo Enter = 9
       for ASUS Enter = 2
       for Apple Enter = 1
       for DELL Enter = 4
       for RedmiBook Enter = 14
       for acer Enter = 18
       for realme Enter = 20
       for HP Enter = 6
       for MSI Enter = 11
       for SAMSUNG Enter = 15
       for Infinix Enter = 7
       for ALIENWARE Enter = 0
       for GIGABYTE Enter = 5
       for Avita Enter = 3
       for Mi Enter = 12
       for MICROSOFT Enter = 10
       for LG Enter = 8
       for lenovo Enter = 19
       for Vaio Enter = 17
       for Ultimus Enter = 16
       for Nokia Enter = 13
        
        '''
    )
    
    print('*'*100)
    print('Processor')
    print(
        '''
        for Intel i5 11 Gen Enter = 10, for Intel i3 11 gen Enter = 7
        
        for Intel i5 10 gen Enter = 9, for Intel i3 10 gen Enter = 6
        
        for Intel i5 12 gen Enter = 11, for Intel i3 12 gen Enter = 8
        
        for Intel i7 12 gen Enter = 12, for Intel i9 12 gen Enter = 13
        
        for Intel i9 13 gen Enter = 14
                     
        for Apple M1 Enter = 4, for Apple M2 Enter = 5
        
        for AMD Ryzen 3 Enter = 0, for AMD Ryzen 7 Enter = 2
        
        for AMD Ryzen 5 Enter = 1, for AMD Ryzen 9 Enter = 3
        
        for Others Enter = 15
        '''
    
    )
    print('*'*100)
    print('RAM')
    print(
        '''
        for 16 GB RAM Enter = 0
        for 8 GB RAM Enter = 2
        for 4 GB RAM Enter = 1
        
        '''
    
    )
    print('*'*100)
    print('Operating System')
    print(
        '''
        for Windows 11 Enter = 4,for DOS OS Enter = 0
        
        for Mac OS Enter = 1,for Windows 10 Enter = 3
        
                   for Other Enter  =2
        '''
    
    )
    print('*'*100)
    print('Storage')
    print(
        '''
        for 512 GB SSD Enter = 4,for 256 GB SSD Enter = 3,for 1 TB SSD Enter = 0
        
        for 2 TB SSD Enter = 2,for 2 TB HDD Enter = 1
        
                  for Other Enter=5
        '''
    
    )
    print('*'*100)
    print('Display')
    print(
        '''
        Choose Display size from given option
        [15.6 , 14.0  , 13.3 , 17.3 , 13.6 , 17.0  , 11.6 , 16.0  , 16.1 ,
         13.4 , 16.2 , 14.2 , 14.5 , 14.1 , 14.96, 13.5 , 35.0  , 16.6 ,
         15.0  , 15.3 , 12.0 ]
        '''
    
    )
    Name = int(input('Enter The Laptop brands Name :- '))
    Processor = int(input('Enter Processor :- '))
    Ram = int(input('Enter Ram :- '))
    OS = int(input('Enter Operating System :- '))
    Storage = int(input('Enter Storage Capacity :- '))
    Display = float(input('Enter Display Size :- '))
    
    newx = [Name, Processor, Ram, OS, Storage, Display]
    Predicted_Price = gbr.predict([newx])[0]
    print('Price of laptop will be :', Predicted_Price)
    return Predicted_Price

# %%
price_predicts()
# Out:
# ****************************************************************************************************
# Laptops Name
#
#        for Lenovo Enter = 9
#        for ASUS Enter = 2
#        for Apple Enter = 1
#        for DELL Enter = 4
#        for RedmiBook Enter = 14
#        for acer Enter = 18
#        for realme Enter = 20
#        for HP Enter = 6
#        for MSI Enter = 11
#        for SAMSUNG Enter = 15
#        for Infinix Enter = 7
#        for ALIENWARE Enter = 0
#        for GIGABYTE Enter = 5
#        for Avita Enter = 3
#        for Mi Enter = 12
#        for MICROSOFT Enter = 10
#        for LG Enter = 8
#        for lenovo Enter = 19
#        for Vaio Enter = 17
#        for Ultimus Enter = 16
#        for Nokia Enter = 13
#
#
# ****************************************************************************************************
# Processor
#
#         for Intel i5 11 Gen Enter = 10, for Intel i3 11 gen Enter = 7
#
# ...
